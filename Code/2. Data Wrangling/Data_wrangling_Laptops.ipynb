# %%
import pandas as pd
import numpy as np
import gzip
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sns
import matplotlib.colors as colors
# %matplotlib inline
from datetime import datetime
import dask.bag as db

# %%
product_reviews_hp3 = pd.read_csv('Product_reviews_laptops.csv')

# %%
product_reviews_hp3.head()
# Out:
#    Rating  verified   reviewTime      reviewerID        asin  \
# 0       5      True  10 11, 2014  A36O9HQS83TUX6  1254875778
# 1       5      True  08 28, 2014  A358J4WU5B0Y9Q  1254875778
# 2       5      True  12 27, 2013  A1QSBRR1IFFSD0  1254875778
# 3       5      True  07 11, 2013  A2UGZCGCYPBMNA  1254875778
# 4       1      True  04 29, 2013  A3H150XFJ7S4KE  1254875778
#
#              reviewerName                                         reviewText  \
# 0  Rafael Antonio herrera                  excellent salesman problem solved
# 1                     G4M  Received on time. Great RAM, Got them to be us...
# 2               Tech nerd  No issues here. Used this RAM to double my cur...
# 3            Larry Butler  2GB really peps up a Win7 netbook.  How stupid...
# 4            93TransAmLT1  Amamax sent me the wrong ram to start with, I ...
#
#                                              summary  unixReviewTime  \
# 0                                         Five Stars      1412985600
# 1  Great RAM, Got them to be used with SuperMicro...      1409184000
# 2                                   Works perfectly.      1388102400
# 3                       Good memory at a great price      1373500800
# 4  This comany is a joke, DON'T buy from them unl...      1367193600
#
#                                             category  ... also_buy  \
# 0  ['Electronics', 'Computers &amp; Accessories',...  ...       []
# 1  ['Electronics', 'Computers &amp; Accessories',...  ...       []
# 2  ['Electronics', 'Computers &amp; Accessories',...  ...       []
# 3  ['Electronics', 'Computers &amp; Accessories',...  ...       []
# 4  ['Electronics', 'Computers &amp; Accessories',...  ...       []
#
#                                                tech2  brand       feature  \
# 0   class="a-keyvalue prodDetTable" role="present...   Dell  ['Hnix 2gb']
# 1   class="a-keyvalue prodDetTable" role="present...   Dell  ['Hnix 2gb']
# 2   class="a-keyvalue prodDetTable" role="present...   Dell  ['Hnix 2gb']
# 3   class="a-keyvalue prodDetTable" role="present...   Dell  ['Hnix 2gb']
# 4   class="a-keyvalue prodDetTable" role="present...   Dell  ['Hnix 2gb']
#
#                                                 rank  \
# 0  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 1  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 2  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 3  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 4  ['>#3,132 in Computers &amp; Accessories &gt; ...
#
#                                            also_view   main_cat  \
# 0  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 1  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 2  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 3  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 4  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
#
#                                         similar_item              date  price
# 0   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 1   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 2   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 3   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 4   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
#
# [5 rows x 24 columns]

# %%
product_reviews_hp3['review_text'] = product_reviews_hp3[['summary', 'reviewText']].apply(lambda x: " ".join(str(y) for y in x if str(y) != 'nan'), axis = 1)
product_reviews_hp4 = product_reviews_hp3.drop(['reviewText', 'summary'], axis = 1)
product_reviews_hp4.head()
# Out:
#    Rating  verified   reviewTime      reviewerID        asin  \
# 0       5      True  10 11, 2014  A36O9HQS83TUX6  1254875778
# 1       5      True  08 28, 2014  A358J4WU5B0Y9Q  1254875778
# 2       5      True  12 27, 2013  A1QSBRR1IFFSD0  1254875778
# 3       5      True  07 11, 2013  A2UGZCGCYPBMNA  1254875778
# 4       1      True  04 29, 2013  A3H150XFJ7S4KE  1254875778
#
#              reviewerName  unixReviewTime  \
# 0  Rafael Antonio herrera      1412985600
# 1                     G4M      1409184000
# 2               Tech nerd      1388102400
# 3            Larry Butler      1373500800
# 4            93TransAmLT1      1367193600
#
#                                             category  \
# 0  ['Electronics', 'Computers &amp; Accessories',...
# 1  ['Electronics', 'Computers &amp; Accessories',...
# 2  ['Electronics', 'Computers &amp; Accessories',...
# 3  ['Electronics', 'Computers &amp; Accessories',...
# 4  ['Electronics', 'Computers &amp; Accessories',...
#
#                                                tech1  \
# 0   class="a-keyvalue prodDetTable" role="present...
# 1   class="a-keyvalue prodDetTable" role="present...
# 2   class="a-keyvalue prodDetTable" role="present...
# 3   class="a-keyvalue prodDetTable" role="present...
# 4   class="a-keyvalue prodDetTable" role="present...
#
#                                          description  ...  \
# 0  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  ...
# 1  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  ...
# 2  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  ...
# 3  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  ...
# 4  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  ...
#
#                                                tech2 brand       feature  \
# 0   class="a-keyvalue prodDetTable" role="present...  Dell  ['Hnix 2gb']
# 1   class="a-keyvalue prodDetTable" role="present...  Dell  ['Hnix 2gb']
# 2   class="a-keyvalue prodDetTable" role="present...  Dell  ['Hnix 2gb']
# 3   class="a-keyvalue prodDetTable" role="present...  Dell  ['Hnix 2gb']
# 4   class="a-keyvalue prodDetTable" role="present...  Dell  ['Hnix 2gb']
#
#                                                 rank  \
# 0  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 1  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 2  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 3  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 4  ['>#3,132 in Computers &amp; Accessories &gt; ...
#
#                                            also_view   main_cat  \
# 0  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 1  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 2  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 3  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 4  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
#
#                                         similar_item              date  price  \
# 0   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 1   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 2   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 3   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 4   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
#
#                                          review_text
# 0       Five Stars excellent salesman problem solved
# 1  Great RAM, Got them to be used with SuperMicro...
# 2  Works perfectly. No issues here. Used this RAM...
# 3  Good memory at a great price 2GB really peps u...
# 4  This comany is a joke, DON'T buy from them unl...
#
# [5 rows x 23 columns]

# %%
product_reviews_hp4['time'] = product_reviews_hp4.reviewTime.str.replace(',', "")
product_reviews_hp4['time'] = pd.to_datetime(product_reviews_hp4['time'], format = '%m %d %Y')

# Drop redundant 'reviewTime' column
product_reviews_hp4 = product_reviews_hp4.drop('reviewTime', axis = 1)
product_reviews_hp4.head()
# Out:
#    Rating  verified      reviewerID        asin            reviewerName  \
# 0       5      True  A36O9HQS83TUX6  1254875778  Rafael Antonio herrera
# 1       5      True  A358J4WU5B0Y9Q  1254875778                     G4M
# 2       5      True  A1QSBRR1IFFSD0  1254875778               Tech nerd
# 3       5      True  A2UGZCGCYPBMNA  1254875778            Larry Butler
# 4       1      True  A3H150XFJ7S4KE  1254875778            93TransAmLT1
#
#    unixReviewTime                                           category  \
# 0      1412985600  ['Electronics', 'Computers &amp; Accessories',...
# 1      1409184000  ['Electronics', 'Computers &amp; Accessories',...
# 2      1388102400  ['Electronics', 'Computers &amp; Accessories',...
# 3      1373500800  ['Electronics', 'Computers &amp; Accessories',...
# 4      1367193600  ['Electronics', 'Computers &amp; Accessories',...
#
#                                                tech1  \
# 0   class="a-keyvalue prodDetTable" role="present...
# 1   class="a-keyvalue prodDetTable" role="present...
# 2   class="a-keyvalue prodDetTable" role="present...
# 3   class="a-keyvalue prodDetTable" role="present...
# 4   class="a-keyvalue prodDetTable" role="present...
#
#                                          description  fit  ... brand  \
# 0  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  Dell
# 1  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  Dell
# 2  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  Dell
# 3  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  Dell
# 4  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  Dell
#
#         feature                                               rank  \
# 0  ['Hnix 2gb']  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 1  ['Hnix 2gb']  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 2  ['Hnix 2gb']  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 3  ['Hnix 2gb']  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 4  ['Hnix 2gb']  ['>#3,132 in Computers &amp; Accessories &gt; ...
#
#                                            also_view   main_cat  \
# 0  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 1  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 2  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 3  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 4  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
#
#                                         similar_item              date  price  \
# 0   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 1   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 2   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 3   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 4   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
#
#                                          review_text       time
# 0       Five Stars excellent salesman problem solved 2014-10-11
# 1  Great RAM, Got them to be used with SuperMicro... 2014-08-28
# 2  Works perfectly. No issues here. Used this RAM... 2013-12-27
# 3  Good memory at a great price 2GB really peps u... 2013-07-11
# 4  This comany is a joke, DON'T buy from them unl... 2013-04-29
#
# [5 rows x 23 columns]

# %%
#example
product_reviews_hp4['review_text'][1263]
# Out:
# 'Four Stars good working product'

# %%
good_rate = len(product_reviews_hp4[product_reviews_hp4['Rating'] >= 3])
bad_rate = len(product_reviews_hp4[product_reviews_hp4['Rating'] < 3])

# Printing rates and their total numbers
print ('Good ratings : {} reviews for Heaphones products'.format(good_rate))
print ('Bad ratings : {} reviews for Headphones products'.format(bad_rate))
# Out:
# Good ratings : 27094 reviews for Heaphones products
# Bad ratings : 3246 reviews for Headphones products

# %%
product_reviews_hp4['rating_class'] = product_reviews_hp4['Rating'].apply(lambda x: 'bad' if x < 3 else'good')
product_reviews_hp4.head()
# Out:
#    Rating  verified      reviewerID        asin            reviewerName  \
# 0       5      True  A36O9HQS83TUX6  1254875778  Rafael Antonio herrera
# 1       5      True  A358J4WU5B0Y9Q  1254875778                     G4M
# 2       5      True  A1QSBRR1IFFSD0  1254875778               Tech nerd
# 3       5      True  A2UGZCGCYPBMNA  1254875778            Larry Butler
# 4       1      True  A3H150XFJ7S4KE  1254875778            93TransAmLT1
#
#    unixReviewTime                                           category  \
# 0      1412985600  ['Electronics', 'Computers &amp; Accessories',...
# 1      1409184000  ['Electronics', 'Computers &amp; Accessories',...
# 2      1388102400  ['Electronics', 'Computers &amp; Accessories',...
# 3      1373500800  ['Electronics', 'Computers &amp; Accessories',...
# 4      1367193600  ['Electronics', 'Computers &amp; Accessories',...
#
#                                                tech1  \
# 0   class="a-keyvalue prodDetTable" role="present...
# 1   class="a-keyvalue prodDetTable" role="present...
# 2   class="a-keyvalue prodDetTable" role="present...
# 3   class="a-keyvalue prodDetTable" role="present...
# 4   class="a-keyvalue prodDetTable" role="present...
#
#                                          description  fit  ...       feature  \
# 0  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  ['Hnix 2gb']
# 1  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  ['Hnix 2gb']
# 2  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  ['Hnix 2gb']
# 3  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  ['Hnix 2gb']
# 4  ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  NaN  ...  ['Hnix 2gb']
#
#                                                 rank  \
# 0  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 1  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 2  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 3  ['>#3,132 in Computers &amp; Accessories &gt; ...
# 4  ['>#3,132 in Computers &amp; Accessories &gt; ...
#
#                                            also_view   main_cat  \
# 0  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 1  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 2  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 3  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
# 4  ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  Computers
#
#                                         similar_item              date  price  \
# 0   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 1   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 2   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 3   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
# 4   class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012  $8.95
#
#                                          review_text       time rating_class
# 0       Five Stars excellent salesman problem solved 2014-10-11         good
# 1  Great RAM, Got them to be used with SuperMicro... 2014-08-28         good
# 2  Works perfectly. No issues here. Used this RAM... 2013-12-27         good
# 3  Good memory at a great price 2GB really peps u... 2013-07-11         good
# 4  This comany is a joke, DON'T buy from them unl... 2013-04-29          bad
#
# [5 rows x 24 columns]

# %%
product_reviews_hp4[product_reviews_hp4.duplicated(['reviewerName','unixReviewTime','asin'],keep= False)]
# Out:
#        Rating  verified      reviewerID        asin reviewerName  \
# 78          5      True  A231WM2Z2JL0U3  B00000J1US      Rheumor
# 79          5      True  A231WM2Z2JL0U3  B00000J1US      Rheumor
# 80          5      True  A238V1XTSK9NFE  B00000J3SA  Andrew Lynn
# 81          5      True  A238V1XTSK9NFE  B00000J3SA  Andrew Lynn
# 82          5      True  A2SKVCKORF8J9Y  B00000J3SA    B. Surkan
# ...       ...       ...             ...         ...          ...
# 30267       5      True  A30QKRDRTZK447  B00032CWPQ      A. Yang
# 30268       3      True   A4KA074LPT2PK  B0003QER5K          sun
# 30269       3      True   A4KA074LPT2PK  B0003QER5K          sun
# 30270       4     False  A3CRF4YS0UWWU6  B0003QER5K      J. Chou
# 30271       4     False  A3CRF4YS0UWWU6  B0003QER5K      J. Chou
#
#        unixReviewTime                                           category  \
# 78         1010880000  ['Electronics', 'Computers & Accessories', 'Co...
# 79         1010880000  ['Electronics', 'Computers & Accessories', 'Co...
# 80          997574400  ['Electronics', 'Computers &amp; Accessories',...
# 81          997574400  ['Electronics', 'Computers &amp; Accessories',...
# 82          984268800  ['Electronics', 'Computers &amp; Accessories',...
# ...               ...                                                ...
# 30267      1110931200  ['Electronics', 'Computers & Accessories', 'Co...
# 30268      1127347200  ['Electronics', 'Computers & Accessories', 'Co...
# 30269      1127347200  ['Electronics', 'Computers & Accessories', 'Co...
# 30270      1111708800  ['Electronics', 'Computers & Accessories', 'Co...
# 30271      1111708800  ['Electronics', 'Computers & Accessories', 'Co...
#
#       tech1                                        description  fit  ...  \
# 78      NaN  ["6 ' IEEE - 1284 PRINTER CABLE", 'All major p...  NaN  ...
# 79      NaN  ["6 ' IEEE - 1284 PRINTER CABLE", 'All major p...  NaN  ...
# 80      NaN                                                 []  NaN  ...
# 81      NaN                                                 []  NaN  ...
# 82      NaN                                                 []  NaN  ...
# ...     ...                                                ...  ...  ...
# 30267   NaN  ['Silent CPU cooler built with pure copper for...  NaN  ...
# 30268   NaN  ['INTEL (WM3B2915ABGNAX) Intel - Intel PRO/Wir...  NaN  ...
# 30269   NaN  ['INTEL (WM3B2915ABGNAX) Intel - Intel PRO/Wir...  NaN  ...
# 30270   NaN  ['INTEL (WM3B2915ABGNAX) Intel - Intel PRO/Wir...  NaN  ...
# 30271   NaN  ['INTEL (WM3B2915ABGNAX) Intel - Intel PRO/Wir...  NaN  ...
#
#                                                  feature  \
# 78     ['IEEE 1284 A-B Cable', 'Low capacitance', 'Im...
# 79     ['IEEE 1284 A-B Cable', 'Low capacitance', 'Im...
# 80     ['Inexpensive CompactFlash card reader solutio...
# 81     ['Inexpensive CompactFlash card reader solutio...
# 82     ['Inexpensive CompactFlash card reader solutio...
# ...                                                  ...
# 30267  ['Pure copper base materials ensure excellent ...
# 30268  ['Intel Wireless Coexistence System support en...
# 30269  ['Intel Wireless Coexistence System support en...
# 30270  ['Intel Wireless Coexistence System support en...
# 30271  ['Intel Wireless Coexistence System support en...
#
#                                                     rank  \
# 78     ['>#71 in Electronics > Accessories & Supplies...
# 79     ['>#71 in Electronics > Accessories & Supplies...
# 80     ['>#1,236 in Electronics &gt; Accessories &amp...
# 81     ['>#1,236 in Electronics &gt; Accessories &amp...
# 82     ['>#1,236 in Electronics &gt; Accessories &amp...
# ...                                                  ...
# 30267  ['>#2,512 in Electronics > Computers & Accesso...
# 30268  ['>#1,434 in Electronics > Computers & Accesso...
# 30269  ['>#1,434 in Electronics > Computers & Accesso...
# 30270  ['>#1,434 in Electronics > Computers & Accesso...
# 30271  ['>#1,434 in Electronics > Computers & Accesso...
#
#                                                also_view         main_cat  \
# 78     ['B00000J1U9', 'B0000512GZ', 'B012FF3CW0', 'B0...  All Electronics
# 79     ['B00000J1U9', 'B0000512GZ', 'B012FF3CW0', 'B0...  All Electronics
# 80                                                    []  All Electronics
# 81                                                    []  All Electronics
# 82                                                    []  All Electronics
# ...                                                  ...              ...
# 30267                                                 []  All Electronics
# 30268                                                 []  All Electronics
# 30269                                                 []  All Electronics
# 30270                                                 []  All Electronics
# 30271                                                 []  All Electronics
#
#                                             similar_item               date  \
# 78      class="a-bordered a-horizontal-stripes  a-spa...       June 1, 1999
# 79      class="a-bordered a-horizontal-stripes  a-spa...       June 1, 1999
# 80                                                   NaN   January 25, 2001
# 81                                                   NaN   January 25, 2001
# 82                                                   NaN   January 25, 2001
# ...                                                  ...                ...
# 30267                                                NaN       July 7, 2004
# 30268                                                NaN  September 9, 2004
# 30269                                                NaN  September 9, 2004
# 30270                                                NaN  September 9, 2004
# 30271                                                NaN  September 9, 2004
#
#         price                                        review_text       time  \
# 78     $13.00  Never had a problem.... I have lots of Belkin ... 2002-01-13
# 79     $13.00  Never had a problem.... I have lots of Belkin ... 2002-01-13
# 80        NaN  Convenient little device If you're like me and... 2001-08-12
# 81        NaN  Convenient little device If you're like me and... 2001-08-12
# 82        NaN  Truly plug and play... I plugged this adapter ... 2001-03-11
# ...       ...                                                ...        ...
# 30267     NaN  happy with purchase, I highly recommend this f... 2005-03-16
# 30268     NaN  if you have IBM laptop (T40 etc.) The card loo... 2005-09-22
# 30269     NaN  if you have IBM laptop (T40 etc.) The card loo... 2005-09-22
# 30270     NaN  No software The only problem I have with this ... 2005-03-25
# 30271     NaN  No software The only problem I have with this ... 2005-03-25
#
#       rating_class
# 78            good
# 79            good
# 80            good
# 81            good
# 82            good
# ...            ...
# 30267         good
# 30268         good
# 30269         good
# 30270         good
# 30271         good
#
# [30194 rows x 24 columns]

# %%
product_reviews_hp4 = product_reviews_hp4.drop_duplicates(['asin','reviewerName', 'unixReviewTime'], keep = 'first')

# %%
product_reviews_hp4.shape
# Out:
# (15227, 21)

# %%
product_reviews_hp4.columns
# Out:
# Index(['Rating', 'verified', 'reviewerID', 'asin', 'reviewerName',
#        'unixReviewTime', 'category', 'description', 'title', 'also_buy',
#        'brand', 'feature', 'rank', 'also_view', 'main_cat', 'similar_item',
#        'date', 'price', 'review_text', 'time', 'rating_class'],
#       dtype='object')

# %%
product_reviews_hp4.transpose()
# Out:
#                                                             0      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A36O9HQS83TUX6
# asin                                                   1254875778
# reviewerName                               Rafael Antonio herrera
# unixReviewTime                                         1412985600
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text          Five Stars excellent salesman problem solved
# time                                          2014-10-11 00:00:00
# rating_class                                                 good
#
#                                                             1      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A358J4WU5B0Y9Q
# asin                                                   1254875778
# reviewerName                                                  G4M
# unixReviewTime                                         1409184000
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text     Great RAM, Got them to be used with SuperMicro...
# time                                          2014-08-28 00:00:00
# rating_class                                                 good
#
#                                                             2      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A1QSBRR1IFFSD0
# asin                                                   1254875778
# reviewerName                                            Tech nerd
# unixReviewTime                                         1388102400
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text     Works perfectly. No issues here. Used this RAM...
# time                                          2013-12-27 00:00:00
# rating_class                                                 good
#
#                                                             3      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A2UGZCGCYPBMNA
# asin                                                   1254875778
# reviewerName                                         Larry Butler
# unixReviewTime                                         1373500800
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text     Good memory at a great price 2GB really peps u...
# time                                          2013-07-11 00:00:00
# rating_class                                                 good
#
#                                                             4      \
# Rating                                                          1
# verified                                                     True
# reviewerID                                         A3H150XFJ7S4KE
# asin                                                   1254875778
# reviewerName                                         93TransAmLT1
# unixReviewTime                                         1367193600
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text     This comany is a joke, DON'T buy from them unl...
# time                                          2013-04-29 00:00:00
# rating_class                                                  bad
#
#                                                             5      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A2CRZHZILAYX3C
# asin                                                   1254875778
# reviewerName                                  Fedro Ponce de Leon
# unixReviewTime                                         1474329600
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text        Five Stars Worked flasslessly on my Dell E6430
# time                                          2016-09-20 00:00:00
# rating_class                                                 good
#
#                                                             6      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                          AO2GO2MMKHLFB
# asin                                                   1254875778
# reviewerName                                 ThorThimbleOfGorbash
# unixReviewTime                                         1470009600
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text     Five Stars Worked like a charm in a HP TouchSm...
# time                                          2016-08-01 00:00:00
# rating_class                                                 good
#
#                                                             7      \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A11951M7SKS5SA
# asin                                                   1254875778
# reviewerName                                          psycho_raze
# unixReviewTime                                         1468713600
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text                         Five Stars Works as expected.
# time                                          2016-07-17 00:00:00
# rating_class                                                 good
#
#                                                             8      \
# Rating                                                          3
# verified                                                    False
# reviewerID                                         A2XPKCTG52CEPW
# asin                                                   1254875778
# reviewerName                                               Max M.
# unixReviewTime                                         1460419200
# category        ['Electronics', 'Computers &amp; Accessories',...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...
# also_buy                                                       []
# brand                                                        Dell
# feature                                              ['Hnix 2gb']
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# main_cat                                                Computers
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...
# date                                             October 30, 2012
# price                                                       $8.95
# review_text     the other one works great. We bought two of th...
# time                                          2016-04-12 00:00:00
# rating_class                                                 good
#
#                                                             9      ...  \
# Rating                                                          4  ...
# verified                                                     True  ...
# reviewerID                                          AJ5WEAIVBLGGB  ...
# asin                                                   1254875778  ...
# reviewerName                                               Nalon1  ...
# unixReviewTime                                         1459641600  ...
# category        ['Electronics', 'Computers &amp; Accessories',...  ...
# description     ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...  ...
# title           Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...  ...
# also_buy                                                       []  ...
# brand                                                        Dell  ...
# feature                                              ['Hnix 2gb']  ...
# rank            ['>#3,132 in Computers &amp; Accessories &gt; ...  ...
# also_view       ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...  ...
# main_cat                                                Computers  ...
# similar_item     class="a-bordered a-horizontal-stripes  a-spa...  ...
# date                                             October 30, 2012  ...
# price                                                       $8.95  ...
# review_text     If you need it, get it Its RAM, it works. Make...  ...
# time                                          2016-04-03 00:00:00  ...
# rating_class                                                 good  ...
#
#                                                             30330  \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A3D7XSIL9FRCBT
# asin                                                   B00062NHTS
# reviewerName                                     Harry Abramowski
# unixReviewTime                                         1266537600
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     a perfect solution to my 1 TOSlink input probl...
# time                                          2010-02-19 00:00:00
# rating_class                                                 good
#
#                                                             30331  \
# Rating                                                          1
# verified                                                     True
# reviewerID                                         A20A7LT4QCKQDK
# asin                                                   B00062NHTS
# reviewerName                                           Goodknight
# unixReviewTime                                         1264723200
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     Returned the switch that wouldn't. I order thi...
# time                                          2010-01-29 00:00:00
# rating_class                                                  bad
#
#                                                             30332  \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A2UO5PG4W4ONAO
# asin                                                   B00062NHTS
# reviewerName                                                YoBro
# unixReviewTime                                         1261094400
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     Optical Switch Solution I only use the optical...
# time                                          2009-12-18 00:00:00
# rating_class                                                 good
#
#                                                             30333  \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A1VNZN4R20WFQA
# asin                                                   B00062NHTS
# reviewerName                                          David Nobel
# unixReviewTime                                         1258243200
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     Pleasantly surprised with this switch I purcha...
# time                                          2009-11-15 00:00:00
# rating_class                                                 good
#
#                                                             30334  \
# Rating                                                          4
# verified                                                     True
# reviewerID                                          ARDG26MFBQQ52
# asin                                                   B00062NHTS
# reviewerName                                          John Hopper
# unixReviewTime                                         1256860800
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     D.O.A.-Waiting to see what happens.../Updated ...
# time                                          2009-10-30 00:00:00
# rating_class                                                 good
#
#                                                             30335  \
# Rating                                                          4
# verified                                                     True
# reviewerID                                         A1I4L57SYKLRSE
# asin                                                   B00062NHTS
# reviewerName                                                Ricky
# unixReviewTime                                         1253145600
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     Does what it's made to do It might be nice to ...
# time                                          2009-09-17 00:00:00
# rating_class                                                 good
#
#                                                             30336  \
# Rating                                                          5
# verified                                                     True
# reviewerID                                         A2KQYPT2JWEZEL
# asin                                                   B00062NHTS
# reviewerName                                             R. Chang
# unixReviewTime                                         1253145600
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     Works great - no noticeable detrioration of au...
# time                                          2009-09-17 00:00:00
# rating_class                                                 good
#
#                                                             30337  \
# Rating                                                          3
# verified                                                     True
# reviewerID                                         A18IPVJC3EGSQF
# asin                                                   B00062NHTS
# reviewerName                                           Kasey Wade
# unixReviewTime                                         1253145600
# category        ['Electronics', 'Accessories &amp; Supplies', ...
# description     ["DVD players, VCRs, DBS receivers, video game...
# title           Nyrius SW200 S-Video Composite &amp; Digital O...
# also_buy                                                       []
# brand                                                        SVAT
# feature         ["Expand the capacity of your home theater's a...
# rank            ['>#1,994 in Electronics &gt; Accessories &amp...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              August 23, 2005
# price                                                         NaN
# review_text     Great when it works! Other than the fact that ...
# time                                          2009-09-17 00:00:00
# rating_class                                                 good
#
#                                                             30338  \
# Rating                                                          5
# verified                                                    False
# reviewerID                                         A1FQKPQCW96MF8
# asin                                                   B00062URN2
# reviewerName                                                  LEE
# unixReviewTime                                         1135123200
# category        ['Electronics', 'Portable Audio &amp; Video', ...
# description     ["If you lead an active lifestyle, then this C...
# title           Case Logic Portable MP3 Player Case (MPC 7) (M...
# also_buy                                                       []
# brand                                                  Case Logic
# feature         ['Case Logic MPC7 Neoprene MP3 Player Case Gen...
# rank            ['>#5,577 in Electronics &gt; Portable Audio &...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              October 2, 2001
# price                                                      $16.95
# review_text     Perfect fit for iPod 20GB (4th generation mono...
# time                                          2005-12-21 00:00:00
# rating_class                                                 good
#
#                                                             30339
# Rating                                                          5
# verified                                                    False
# reviewerID                                         A1LX9GSMN66L7E
# asin                                                   B00062URN2
# reviewerName                                         Ellis Godard
# unixReviewTime                                         1119744000
# category        ['Electronics', 'Portable Audio &amp; Video', ...
# description     ["If you lead an active lifestyle, then this C...
# title           Case Logic Portable MP3 Player Case (MPC 7) (M...
# also_buy                                                       []
# brand                                                  Case Logic
# feature         ['Case Logic MPC7 Neoprene MP3 Player Case Gen...
# rank            ['>#5,577 in Electronics &gt; Portable Audio &...
# also_view                                                      []
# main_cat                                 Home Audio &amp; Theater
# similar_item                                                  NaN
# date                                              October 2, 2001
# price                                                      $16.95
# review_text     Perfect size, features - solid brand name, for...
# time                                          2005-06-26 00:00:00
# rating_class                                                 good
#
# [21 rows x 15227 columns]

# %%
product_reviews_hp4=product_reviews_hp4.drop(columns =['fit'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-a1ecc2f098ef> in <module>
# ----> 1 product_reviews_hp4=product_reviews_hp4.drop(columns =['fit'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['fit'] not found in axis"

# %%
product_reviews_hp4.columns

# %%
product_reviews_hp4.shape
# Out:
# (15227, 21)

# %%
product_reviews_hp4 = product_reviews_hp4.drop_duplicates(['asin','reviewerName', 'unixReviewTime'], keep = 'first')
product_reviews_hp4
# Out:
#        Rating  verified      reviewerID        asin            reviewerName  \
# 0           5      True  A36O9HQS83TUX6  1254875778  Rafael Antonio herrera
# 1           5      True  A358J4WU5B0Y9Q  1254875778                     G4M
# 2           5      True  A1QSBRR1IFFSD0  1254875778               Tech nerd
# 3           5      True  A2UGZCGCYPBMNA  1254875778            Larry Butler
# 4           1      True  A3H150XFJ7S4KE  1254875778            93TransAmLT1
# ...       ...       ...             ...         ...                     ...
# 30335       4      True  A1I4L57SYKLRSE  B00062NHTS                   Ricky
# 30336       5      True  A2KQYPT2JWEZEL  B00062NHTS                R. Chang
# 30337       3      True  A18IPVJC3EGSQF  B00062NHTS              Kasey Wade
# 30338       5     False  A1FQKPQCW96MF8  B00062URN2                     LEE
# 30339       5     False  A1LX9GSMN66L7E  B00062URN2            Ellis Godard
#
#        unixReviewTime                                           category  \
# 0          1412985600  ['Electronics', 'Computers &amp; Accessories',...
# 1          1409184000  ['Electronics', 'Computers &amp; Accessories',...
# 2          1388102400  ['Electronics', 'Computers &amp; Accessories',...
# 3          1373500800  ['Electronics', 'Computers &amp; Accessories',...
# 4          1367193600  ['Electronics', 'Computers &amp; Accessories',...
# ...               ...                                                ...
# 30335      1253145600  ['Electronics', 'Accessories &amp; Supplies', ...
# 30336      1253145600  ['Electronics', 'Accessories &amp; Supplies', ...
# 30337      1253145600  ['Electronics', 'Accessories &amp; Supplies', ...
# 30338      1135123200  ['Electronics', 'Portable Audio &amp; Video', ...
# 30339      1119744000  ['Electronics', 'Portable Audio &amp; Video', ...
#
#                                              description  \
# 0      ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# 1      ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# 2      ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# 3      ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# 4      ['REFURBISHED - Hynix 2GB DDR3 Memory SO-DIMM ...
# ...                                                  ...
# 30335  ["DVD players, VCRs, DBS receivers, video game...
# 30336  ["DVD players, VCRs, DBS receivers, video game...
# 30337  ["DVD players, VCRs, DBS receivers, video game...
# 30338  ["If you lead an active lifestyle, then this C...
# 30339  ["If you lead an active lifestyle, then this C...
#
#                                                    title also_buy  ...  \
# 0      Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...       []  ...
# 1      Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...       []  ...
# 2      Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...       []  ...
# 3      Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...       []  ...
# 4      Hynix 2GB DDR3 Memory SO-DIMM 204pin PC3-10600...       []  ...
# ...                                                  ...      ...  ...
# 30335  Nyrius SW200 S-Video Composite &amp; Digital O...       []  ...
# 30336  Nyrius SW200 S-Video Composite &amp; Digital O...       []  ...
# 30337  Nyrius SW200 S-Video Composite &amp; Digital O...       []  ...
# 30338  Case Logic Portable MP3 Player Case (MPC 7) (M...       []  ...
# 30339  Case Logic Portable MP3 Player Case (MPC 7) (M...       []  ...
#
#                                                  feature  \
# 0                                           ['Hnix 2gb']
# 1                                           ['Hnix 2gb']
# 2                                           ['Hnix 2gb']
# 3                                           ['Hnix 2gb']
# 4                                           ['Hnix 2gb']
# ...                                                  ...
# 30335  ["Expand the capacity of your home theater's a...
# 30336  ["Expand the capacity of your home theater's a...
# 30337  ["Expand the capacity of your home theater's a...
# 30338  ['Case Logic MPC7 Neoprene MP3 Player Case Gen...
# 30339  ['Case Logic MPC7 Neoprene MP3 Player Case Gen...
#
#                                                     rank  \
# 0      ['>#3,132 in Computers &amp; Accessories &gt; ...
# 1      ['>#3,132 in Computers &amp; Accessories &gt; ...
# 2      ['>#3,132 in Computers &amp; Accessories &gt; ...
# 3      ['>#3,132 in Computers &amp; Accessories &gt; ...
# 4      ['>#3,132 in Computers &amp; Accessories &gt; ...
# ...                                                  ...
# 30335  ['>#1,994 in Electronics &gt; Accessories &amp...
# 30336  ['>#1,994 in Electronics &gt; Accessories &amp...
# 30337  ['>#1,994 in Electronics &gt; Accessories &amp...
# 30338  ['>#5,577 in Electronics &gt; Portable Audio &...
# 30339  ['>#5,577 in Electronics &gt; Portable Audio &...
#
#                                                also_view  \
# 0      ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# 1      ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# 2      ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# 3      ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# 4      ['B004K4MZ1E', 'B004K4IULS', 'B005LDLP8W', 'B0...
# ...                                                  ...
# 30335                                                 []
# 30336                                                 []
# 30337                                                 []
# 30338                                                 []
# 30339                                                 []
#
#                        main_cat  \
# 0                     Computers
# 1                     Computers
# 2                     Computers
# 3                     Computers
# 4                     Computers
# ...                         ...
# 30335  Home Audio &amp; Theater
# 30336  Home Audio &amp; Theater
# 30337  Home Audio &amp; Theater
# 30338  Home Audio &amp; Theater
# 30339  Home Audio &amp; Theater
#
#                                             similar_item              date  \
# 0       class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012
# 1       class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012
# 2       class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012
# 3       class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012
# 4       class="a-bordered a-horizontal-stripes  a-spa...  October 30, 2012
# ...                                                  ...               ...
# 30335                                                NaN   August 23, 2005
# 30336                                                NaN   August 23, 2005
# 30337                                                NaN   August 23, 2005
# 30338                                                NaN   October 2, 2001
# 30339                                                NaN   October 2, 2001
#
#         price                                        review_text       time  \
# 0       $8.95       Five Stars excellent salesman problem solved 2014-10-11
# 1       $8.95  Great RAM, Got them to be used with SuperMicro... 2014-08-28
# 2       $8.95  Works perfectly. No issues here. Used this RAM... 2013-12-27
# 3       $8.95  Good memory at a great price 2GB really peps u... 2013-07-11
# 4       $8.95  This comany is a joke, DON'T buy from them unl... 2013-04-29
# ...       ...                                                ...        ...
# 30335     NaN  Does what it's made to do It might be nice to ... 2009-09-17
# 30336     NaN  Works great - no noticeable detrioration of au... 2009-09-17
# 30337     NaN  Great when it works! Other than the fact that ... 2009-09-17
# 30338  $16.95  Perfect fit for iPod 20GB (4th generation mono... 2005-12-21
# 30339  $16.95  Perfect size, features - solid brand name, for... 2005-06-26
#
#       rating_class
# 0             good
# 1             good
# 2             good
# 3             good
# 4              bad
# ...            ...
# 30335         good
# 30336         good
# 30337         good
# 30338         good
# 30339         good
#
# [15227 rows x 21 columns]

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import unicodedata
import contractions
from contractions import CONTRACTION_MAP
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize, sent_tokenize, regexp_tokenize 
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re
# Out:
# [nltk_data] Downloading package punkt to C:\Users\yash
# [nltk_data]     chopra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\yash
# [nltk_data]     chopra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\yash
# [nltk_data]     chopra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
raw_tokens=len([w for t in (product_reviews_hp4["review_text"].apply(word_tokenize)) for w in t])
print('Number of raw tokens: {}'.format(raw_tokens))
# Out:
# Number of raw tokens: 1304436

# %%
import re, string, unicodedata
import nltk
import contractions
from bs4 import BeautifulSoup
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from contractions import CONTRACTION_MAP

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    return text



# Define function to expand contractions
def expand_contractions(text):
    contractions_pattern = re.compile('({})'.format('|'.join(CONTRACTION_MAP.keys())),flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = CONTRACTION_MAP.get(match)\
                        if CONTRACTION_MAP.get(match)\
                        else CONTRACTION_MAP.get(match.lower())
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction
    
    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text


# special_characters removal
def remove_special_characters(text, remove_digits=True):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text


def remove_non_ascii(words):
    """Remove non-ASCII characters from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    return new_words

def to_lowercase(words):
    """Convert all characters to lowercase from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = word.lower()
        new_words.append(new_word)
    return new_words


def remove_punctuation_and_splchars(words):
    """Remove punctuation from list of tokenized words"""
    new_words = []
    for word in words:
        new_word = re.sub(r'[^\w\s]', '', word)
        if new_word != '':
            new_word = remove_special_characters(new_word, True)
            new_words.append(new_word)
    return new_words

def replace_numbers(words):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    p = inflect.engine()
    new_words = []
    for word in words:
        if word.isdigit():
            new_word = p.number_to_words(word)
            new_words.append(new_word)
        else:
            new_words.append(word)
    return new_words

stopword_list= stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
#stopword_list.remove('headphone')
#stopword_list.remove('headphones')
#stopword_list.remove('earbuds')
#stopword_list.remove('bud')
#stopword_list.remove('ear')
#stopword_list.remove('sony')
#stopword_list.remove('product')


def remove_stopwords(words):
    """Remove stop words from list of tokenized words"""
    new_words = []
    for word in words:
        if word not in stopword_list:
            new_words.append(word)
    return new_words

def stem_words(words):
    """Stem words in list of tokenized words"""
    stemmer = LancasterStemmer()
    stems = []
    for word in words:
        stem = stemmer.stem(word)
        stems.append(stem)
    return stems

def lemmatize_verbs(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

def normalize(words):
    words = remove_non_ascii(words)
    words = to_lowercase(words)
    words = remove_punctuation_and_splchars(words)
    words = remove_stopwords(words)
    return words

def lemmatize(words):
    lemmas = lemmatize_verbs(words)
    return lemmas

# %%
def normalize_and_lemmaize(input):
    sample = denoise_text(input)
    sample = expand_contractions(sample)
    sample = remove_special_characters(sample)
    words = nltk.word_tokenize(sample)
    words = normalize(words)
    lemmas = lemmatize(words)
    return ' '.join(lemmas)

# %%
product_reviews_hp4['clean_text'] = product_reviews_hp4['review_text'].map(lambda text: normalize_and_lemmaize(text))

# %%
# Let's put aside number of raw tokens in order to measure of cleaned tokens
from nltk.tokenize import word_tokenize
clean_tokens=len([w for t in (product_reviews_hp4["clean_text"].apply(word_tokenize)) for w in t])
#clean_tokens=len((product_reviews_hp4["clean_text"]))
print('Number of clean tokens: {}\n'.format(clean_tokens))
print('Percentage of removed tokens: {0:.2f}'.format(1-(clean_tokens/raw_tokens)))
# Out:
# Number of clean tokens: 595291
#
# Percentage of removed tokens: 0.54

# %%
product_reviews_hp4.to_csv('clean_review_laptops.csv', sep=',', encoding='utf-8', index = False)

# %%
product_reviews_hp4.to_json('clean_review_laptops.json')
